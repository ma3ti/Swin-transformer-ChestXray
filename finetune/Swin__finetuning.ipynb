# %%
# CLONE GIT REPOSITORY (OR UPLOAD YOURS ALREADY MODFIED)
#!git clone https://github.com/microsoft/Swin-Transformer.git
# !git clone https://github.com/ma3ti/Swin-transformer-ChestXray
# !pip install timm==0.4.12 yacs pyyaml
# Out:
# Cloning into 'Swin-transformer-ChestXray'...
# remote: Enumerating objects: 430, done.
# remote: Counting objects: 100% (430/430), done.
# remote: Compressing objects: 100% (175/175), done.
# remote: Total 430 (delta 258), reused 421 (delta 251), pack-reused 0 (from 0)
# Receiving objects: 100% (430/430), 1.16 MiB | 5.24 MiB/s, done.
# Resolving deltas: 100% (258/258), done.
# ...

# %%
# DOWNLAOD SWIN WEIGHTS
# !wget https://github.com/SwinTransformer/storage/releases/download/v1.0.0/swin_tiny_patch4_window7_224.pth
# Out:
# --2026-01-15 07:46:31--  https://github.com/SwinTransformer/storage/releases/download/v1.0.0/swin_tiny_patch4_window7_224.pth
# Resolving github.com (github.com)... 140.82.116.3
# Connecting to github.com (github.com)|140.82.116.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# %cd /content/Swin-transformer-ChestXray/
# Out:
# /content/Swin-transformer-ChestXray

# %%
# UNZIP DATASET
# !unzip -q "/content/chest_xray_new.zip" -d "/content/dataset/"

# %%
# !ls /content/dataset/chest_xray_new/
# Out:
# test  train  val

# %%
# %pwd
# Out:
# '/content/Swin-transformer-ChestXray'

# %%
# %rm -rf /content/Swin-transformer-ChestXray/output
# %rm -rf /content/Swin-transformer-ChestXray/output_fixed

# %%
# FINE TUNING

# !python -m torch.distributed.launch --nproc_per_node 1 --master_port 12345 main.py \
--cfg configs/swin/chest_xray_finetune.yaml \
--pretrained /content/swin_tiny_patch4_window7_224.pth \
--data-path /content/dataset/chest_xray_new \
--batch-size 32 \
--accumulation-steps 1 \
--opts MODEL.NUM_CLASSES 2
# Out:
# /usr/local/lib/python3.12/dist-packages/torch/distributed/launch.py:207: FutureWarning: The module torch.distributed.launch is deprecated
# and will be removed in future. Use torchrun.
# Note that --use-env is set by default in torchrun.
# If your script expects `--local-rank` argument to be set, please
# change it to read from `os.environ['LOCAL_RANK']` instead. See
# https://pytorch.org/docs/stable/distributed.html#launch-utility for
# further instructions
#
#   main()
# [Warning] Fused window process have not been installed. Please refer to get_started.md for installation.
# Tutel has not been installed. To use Swin-MoE, please install Tutel; otherwise, just ignore this.
# To use FusedLAMB or FusedAdam, please install apex.
# => merge config from configs/swin/chest_xray_finetune.yaml
# RANK and WORLD_SIZE in environ: 0/1
# ...

# %%
import shutil
from google.colab import files

folder_path = 'output'
output_filename = '/content/Swin-Transformer'

shutil.make_archive(output_filename, 'zip', folder_path)
print(f"Creato {output_filename}.zip")

files.download(output_filename + '.zip')
# Out:
# Creato /content/Swin-Transformer/.zip
